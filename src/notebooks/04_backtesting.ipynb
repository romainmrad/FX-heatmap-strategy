# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/backtest/2025-09-19 14:59:20_backtest_history.csv')
df['returns'] = df['Total'].pct_change()
df
# Out:
#             Date         Total           USD     USDSEK=X     USDHKD=X  \
# 0     2015-01-05   9944.414787   9944.414787     0.000000     0.000000
# 1     2015-01-06   9944.959701   9944.959701     0.000000     0.000000
# 2     2015-01-07   9945.504646   9945.504646     0.000000     0.000000
# 3     2015-01-08   9946.049620   9946.049620     0.000000     0.000000
# 4     2015-01-09   9946.594624   9946.594624     0.000000     0.000000
# ...          ...           ...           ...          ...          ...
# 1247  2019-12-24  11160.772112  11160.772112     0.000000     0.000000
# 1248  2019-12-26  11161.995277  11161.995277     0.000000     0.000000
# 1249  2019-12-27  11162.606910      0.000000  8075.158879  6687.174310
# 1250  2019-12-30  11216.892625      0.000000  8046.860947  6719.203549
# 1251  2019-12-31  11238.278044  11238.278044     0.000000     0.000000
#
#          USDCAD=X    USDEUR=X     USDAUD=X     USDDKK=X     USDNZD=X  \
# ...

# %%
mu = df['returns'].mean()
sigma = df['returns'].std()
print(mu/sigma * np.sqrt(12))
# Out:
# 0.15014466577009053
